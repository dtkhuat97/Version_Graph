# %%
from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "18_06_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4
min_version = 1
max_version = 10

#CHANGE
increment = 1000
researched_path = "var_num_nodes/"

while num_node_labels <= 10000:
    #CHANGE
    researched = str(num_node_labels)
    path_og = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    #path_incidence =  "/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_edge_len/"+researched+"/"
    path_index = "/home/dtkhuat/results_version/version_itr/random_graphs_compressed/"+researched_path +researched+"/"
    #call(["mkdir","/home/dtkhuat/results_version/random_graphs/"+researched_path+researched])
    #call(["mkdir",path_index])
    #call(["touch",path_og+date+".csv"])

    
    
    
    for i in range(0,100):
        file_name = "random_"+str(num_node_labels)+"_4_"+str(num_edges)+"_"
        compressed_name = file_name + str(i) +"_" +str(min_version)+"_" + str(max_version) +"_c"
        #call(["/home/dtkhuat/IncidenceTypeRePair/build/./cgraph-cli", "--overwrite", "--rrr", "--verbose", path_og + file_name + str(i)+".ttl",  path_incidence+compressed_name])
        call(["./cgraph-cli", "--overwrite", "--verbose","--format", "hyperedge", "--max-rank", "64" , path_og + file_name + str(i)+"_" +str(min_version)+"_" + str(max_version), path_index + compressed_name])

        '''
        with open(path_og+date+'.csv', 'a') as csv_file:
            fields = [file_name+ str(i)+".ttl", os.stat(path_og + file_name+ str(i)+".ttl").st_size, os.stat(path_incidence+compressed_name).st_size, os.stat(path_index+compressed_name).st_size]
            csv_writer = csv.writer(csv_file, delimiter=',')
            csv_writer.writerow(fields)
        '''
        if(i<99):
            with open('/home/dtkhuat/results_version/version_itr/times/'+ researched_path+ date+ '.csv', 'a') as csv_file:
               #csv_writer = csv.writer(csv_file, delimiter=',')
                csv_file.write(", ")
                csv_file.close()
            #with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+ researched_path+'/timings.csv', 'a') as csv_file:
                #csv_writer = csv.writer(csv_file, delimiter=',')
            #    csv_file.write(", ")
            #    csv_file.close()
        else:
            with open('/home/dtkhuat/results_version/version_itr/times/' + researched_path+ date+ '.csv', 'a') as csv_file:
                csv_file.write("\n")
                csv_file.close()
            #with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+ researched_path+'/timings.csv', 'a') as csv_file:
            #    csv_file.write("\n")
            #    csv_file.close()

    num_node_labels = num_node_labels + increment
# Out:
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_0_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_0_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5812 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_1_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_1_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5747 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_2_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_2_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5698 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_3_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_3_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5715 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_4_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_4_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5792 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_5_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_5_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5781 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_6_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_6_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5653 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_7_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_7_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5747 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_8_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_8_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5765 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_9_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_9_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5768 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_10_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_10_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5793 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_11_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_11_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5814 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_12_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_12_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5716 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_13_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_13_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5792 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_14_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_14_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5682 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_15_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_15_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5729 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_16_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_16_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5649 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_17_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_17_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5770 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_18_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_18_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5763 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_19_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_19_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5792 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000_20_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_nodes/1000/random_1000_4_1000_20_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5836 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_nodes/1000/random_1000_4_1000