# %%
import random
import sys
from subprocess import call
from rdflib import Graph
import pprint
import random

# %%
def write_hyperedge(file_name, hyperedge, version_start, version_end):
    with open(file_name, 'a') as hyperedge_file:
        '''
        s = "<" + str(hyperedge[1]) + ">"
        p = "<" + str(hyperedge[0]) + ">"
        o = "<" + str(hyperedge[2]) + ">"
        v1 = "<" + str(version_start) + ">"
        v2 = "<" + str(version_end) + ">"
        '''
        s = str(hyperedge[0]) 
        p =  str(hyperedge[1]) 
        o =  str(hyperedge[2]) 
        v1 =  str(version_start)
        v2 =   str(version_end) 
        final_edge= p + "\t" + s + "\t" + o + "\t" + v1 + "\t" + v2
        hyperedge_file.write(final_edge + "\n")
        hyperedge_file.close()

# %%
#CHANGE
str_len = 4
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
og_ending = ".ttl"
new_ending = ".nq"
min_version = 1
max_version = 10

#CHANGE
while(max_version <= 100):
    #CHANGE
    call(["mkdir","/home/dtkhuat/results_version/random_graphs/var_version/"+str(max_version)])
    
    for file_num in range(0,100):
        #CHANGE
        path = "/home/dtkhuat/results/random_graphs/var_num_edges/" + str(num_edges) + "/"
        path_v = "/home/dtkhuat/results_version/random_graphs/var_version/" + str(max_version) + "/" + "random_" + str(num_node_labels) + "_" + str(num_edge_labels) + "_" + str(num_edges) + "_" +str(file_num) + "_" +str(min_version) + "_" +str(max_version)
        
        g = Graph()
        g.parse(path + "random_" + str(num_node_labels) + "_" + str(num_edge_labels) + "_" + str(num_edges) + "_" +str(file_num) + og_ending, format='ttl')
        line_counter = 0
        for subject, predicate, object in g:
            #print(subject.replace("file://"+path, ""), predicate.replace("file://"+path, ""), object.replace("file://"+path, ""))
            s = subject.replace("file://"+path, "")
            p = predicate.replace("file://"+path, "")
            o = object.replace("file://"+path, "")
            start = random.randint(min_version,max_version)
            end = random.randint(start,max_version)
            
            
            write_hyperedge(path_v,[s, p, o], start, end)
            line_counter = line_counter + 1
            extender = random.random()
            
            while(extender < 0.1 and end < (max_version-1) and line_counter < num_edges):
                start = random.randint(end+2,max_version)
                end = random.randint(start,max_version)
                write_hyperedge(path_v,[s, p, o], start, end)
                line_counter = line_counter + 1
                extender = random.random()
                if(line_counter >= num_edges):
                    extender = 1
            #CHANGE
            if(line_counter >= num_edges):
                break
    
        
    #CHANGE
    max_version = max_version + 10

# %% [markdown]
# ##GENERATE GRAPH VAR NUM NODES

# %%
#CHANGE
str_len = 4
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
og_ending = ".ttl"
new_ending = ".nq"
min_version = 1
max_version = 10
researched_path = "var_num_nodes/"
increment = 1000
#CHANGE
while(num_node_labels <= 10000):
    #CHANGE
    researched = str(num_node_labels)
    call(["mkdir","/home/dtkhuat/results_version/random_graphs/"+researched_path+researched])
    
    for file_num in range(0,100):
        #CHANGE
        path = "/home/dtkhuat/results/random_graphs/"+researched_path + researched + "/"
        path_v = "/home/dtkhuat/results_version/random_graphs/"+researched_path + researched + "/" + "random_" + str(num_node_labels) + "_" + str(num_edge_labels) + "_" + str(num_edges) + "_" +str(file_num) + "_" +str(min_version) + "_" +str(max_version)
        
        g = Graph()
        g.parse(path + "random_" + str(num_node_labels) + "_" + str(num_edge_labels) + "_" + str(num_edges) + "_" +str(file_num) + og_ending, format='ttl')
        line_counter = 0
        for subject, predicate, object in g:
            #print(subject.replace("file://"+path, ""), predicate.replace("file://"+path, ""), object.replace("file://"+path, ""))
            s = subject.replace("file://"+path, "")
            p = predicate.replace("file://"+path, "")
            o = object.replace("file://"+path, "")
            start = random.randint(min_version,max_version)
            end = random.randint(start,max_version)
            #CHANGE
            
            write_hyperedge(path_v,[s, p, o], start, end)
            line_counter = line_counter + 1
            extender = random.random()
            #CHANGE
            while(extender < 0.1 and end < (max_version-1) and line_counter < num_edges):
                start = random.randint(end+2,max_version)
                end = random.randint(start,max_version)
                write_hyperedge(path_v,[s, p, o], start, end)
                line_counter = line_counter + 1
                extender = random.random()
                if(line_counter >= num_edges):
                    extender = 1
            #CHANGE
            if(line_counter >= num_edges):
                break
    
        
    #CHANGE
    num_node_labels = num_node_labels + increment

# %% [markdown]
# ##GENERATE GRAPH VAR EDGE LEN

# %%
#CHANGE
str_len = 4
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
og_ending = ".ttl"
new_ending = ".nq"
min_version = 1
max_version = 10
researched_path = "var_edge_len/"
increment = 4
#CHANGE
while(str_len <= 64):
    #CHANGE
    researched = str(str_len)
    call(["mkdir","/home/dtkhuat/results_version/random_graphs/"+researched_path+researched])
    
    for file_num in range(0,100):
        #CHANGE
        path = "/home/dtkhuat/results/random_graphs/"+researched_path + researched + "/"
        path_v = "/home/dtkhuat/results_version/random_graphs/"+researched_path + researched + "/" + "random_" + str(num_node_labels) + "_" + str(num_edge_labels) + "_" + str(num_edges) + "_" +str(file_num) + "_" +str(min_version) + "_" +str(max_version)
        
        g = Graph()
        g.parse(path + "random_" + str(num_node_labels) + "_" + str(num_edge_labels) + "_" + str(num_edges) + "_" +str(file_num) + og_ending, format='ttl')
        line_counter = 0
        for subject, predicate, object in g:
            #print(subject.replace("file://"+path, ""), predicate.replace("file://"+path, ""), object.replace("file://"+path, ""))
            s = subject.replace("file://"+path, "")
            p = predicate.replace("file://"+path, "")
            o = object.replace("file://"+path, "")
            start = random.randint(min_version,max_version)
            end = random.randint(start,max_version)
            #CHANGE
            
            write_hyperedge(path_v,[s, p, o], start, end)
            line_counter = line_counter + 1
            extender = random.random()
            #CHANGE
            while(extender < 0.1 and end < (max_version-1) and line_counter < num_edges):
                start = random.randint(end+2,max_version)
                end = random.randint(start,max_version)
                write_hyperedge(path_v,[s, p, o], start, end)
                line_counter = line_counter + 1
                extender = random.random()
                if(line_counter >= num_edges):
                    extender = 1
            #CHANGE
            if(line_counter >= num_edges):
                break
    
        
    #CHANGE
    str_len = str_len + increment

# %% [markdown]
# ##GENERATE GRAPH VAR NUM EDGES

# %%
#CHANGE
str_len = 4
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
og_ending = ".ttl"
new_ending = ".nq"
min_version = 1
max_version = 10
researched_path = "var_num_edges/"
increment = 1000
#CHANGE
while(num_edges <= 10000):
    #CHANGE
    researched = str(num_edges)
    call(["mkdir","/home/dtkhuat/results_version/random_graphs/"+researched_path+researched])
    
    for file_num in range(0,100):
        #CHANGE
        path = "/home/dtkhuat/results/random_graphs/"+researched_path + researched + "/"
        path_v = "/home/dtkhuat/results_version/random_graphs/"+researched_path + researched + "/" + "random_" + str(num_node_labels) + "_" + str(num_edge_labels) + "_" + str(num_edges) + "_" +str(file_num) + "_" +str(min_version) + "_" +str(max_version)
        
        g = Graph()
        g.parse(path + "random_" + str(num_node_labels) + "_" + str(num_edge_labels) + "_" + str(num_edges) + "_" +str(file_num) + og_ending, format='ttl')
        line_counter = 0
        for subject, predicate, object in g:
            #print(subject.replace("file://"+path, ""), predicate.replace("file://"+path, ""), object.replace("file://"+path, ""))
            s = subject.replace("file://"+path, "")
            p = predicate.replace("file://"+path, "")
            o = object.replace("file://"+path, "")
            start = random.randint(min_version,max_version)
            end = random.randint(start,max_version)
            #CHANGE
            
            write_hyperedge(path_v,[s, p, o], start, end)
            line_counter = line_counter + 1
            extender = random.random()
            #CHANGE
            while(extender < 0.1 and end < (max_version-1) and line_counter < num_edges):
                start = random.randint(end+2,max_version)
                end = random.randint(start,max_version)
                write_hyperedge(path_v,[s, p, o], start, end)
                extender = random.random()
                line_counter = line_counter + 1
                if(line_counter >= num_edges):
                    extender = 1
            #CHANGE
            if(line_counter >= num_edges):
                break
    
        
    #CHANGE
    num_edges = num_edges + increment

# %% [markdown]
# ##MAKE SEMI REAL GRAPHS

# %%
#CHANGE
str_len = 4
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
og_ending = ".ttl"
new_ending = ".nq"
min_version = 1
max_version = 10
file_name  = "archiveshub"
file_ending = ".nt"
#CHANGE
while(max_version <= 10):
    #CHANGE
    path = "/home/dtkhuat/eval_datasets/" + file_name +file_ending
    g = Graph()
    g.parse(path)
    for file_num in range(0,5):
        #CHANGE
        
        path_v = "/home/dtkhuat/eval_datasets/semi_real_datasets/" + file_name + str(file_num)
        
        #print("h3")
        
        line_counter = 0
        #print("hi")
        for subject, predicate, object in g:
            #print("hi2")
            #print(subject.replace("file://"+path, ""), predicate.replace("file://"+path, ""), object.replace("file://"+path, ""))
            
            s = subject.replace("file://"+path, "").replace("\t", "").replace("\n","")
            p = predicate.replace("file://"+path, "").replace("\t", "").replace("\n","")
            o = object.replace("file://"+path, "").replace("\t", "").replace("\n","")
            if len(s) > 8000 or len(p) > 8000 or len(o) > 8000:
                continue
            start = random.randint(min_version,max_version)
            end = random.randint(start,max_version)
            
            #print(s,p,o)
            write_hyperedge(path_v,[s, p, o], start, end)
            #line_counter = line_counter + 1
            extender = random.random()
            
            #while(extender < 0.1 and end < (max_version-1) and line_counter < num_edges):
            
            while(extender < 0.1 and end < (max_version-1)):
                start = random.randint(end+2,max_version)
                end = random.randint(start,max_version)
                write_hyperedge(path_v,[s, p, o], start, end)
                #line_counter = line_counter + 1
                extender = random.random()
            
            #CHANGE
            #if(line_counter >= num_edges):
            #    break
    
        
    #CHANGE
    max_version = max_version + 10

# %%
##PREPROCESS REMOVE DUPES
#part = "10"
file_name = "taxonomy3"
path_1 = "/home/dtkhuat/tests/test3" #/eval_datasets/semi_real_datasets/final/"+file_name #CHANGE
path_2 = "/home/dtkhuat/results_version/random_graphs/var_edge_len/60/random_1000_4_1000_0_0_10"#"/home/dtkhuat/eval_datasets/semi_real_datasets/"+ file_name #CHANGE
with open(path_2) as result:
        uniqlines = set(result.readlines())
        with open(path_1, 'w') as rmdup:
            rmdup.writelines(set(uniqlines))
'''


line_counter = 0
prev_line = ""
bla_counter = 0
with open(path_1, 'a') as file_1, open(path_2, 'r') as file_2:
    
    
    if line_counter == 500000:
        file_1.close()
        file_2.close()
   
    for line in file_2:
        if len(line) > 4000:
            continue
        if not line.isascii():
            print(line)
            continue
        if line_counter == 0 :
            file_1.write(line)
            
        
        if "\\t\\t" in line:
            print("hi")
            line = line.replace("\\t\\t", "\\ty\\t")
        
        if line_counter > 0:
            if prev_line == line:
                bla_counter = bla_counter +1
                continue
            else:
                file_1.write(line)
        line_counter = line_counter + 1
        prev_line = line
print(bla_counter)
'''
# Out:
# '\n\n\nline_counter = 0\nprev_line = ""\nbla_counter = 0\nwith open(path_1, \'a\') as file_1, open(path_2, \'r\') as file_2:\n    \n    \n    if line_counter == 500000:\n        file_1.close()\n        file_2.close()\n   \n    for line in file_2:\n        if len(line) > 4000:\n            continue\n        if not line.isascii():\n            print(line)\n            continue\n        if line_counter == 0 :\n            file_1.write(line)\n            \n        \n        if "\\t\\t" in line:\n            print("hi")\n            line = line.replace("\\t\\t", "\\ty\\t")\n        \n        if line_counter > 0:\n            if prev_line == line:\n                bla_counter = bla_counter +1\n                continue\n            else:\n                file_1.write(line)\n        line_counter = line_counter + 1\n        prev_line = line\nprint(bla_counter)\n'

# %%
#find missing
#path_1 = "/home/dtkhuat/tests/test3"
#path_2 = "/home/dtkhuat/tests/test3_dec"
path_1 = "/home/dtkhuat/eval_datasets/semi_real_datasets/final/taxonomy3"
path_2 = "/home/dtkhuat/eval_datasets/semi_real_datasets/final/taxonomy3_dec"

missing = []  
with open(path_1,'r') as a_file:
    a_lines = a_file.readlines()
with open(path_2,'r') as b_file:
    b_lines = b_file.readlines()

for line_a in a_lines:   
    for line_b in b_lines: 
        if line_a in line_b:
            break
    else: 
        missing.append(line_a)  

print(len(missing))
for miss in missing:
    print(miss)

# %% [markdown]
# ##GENERATE SINGLE TEST GRAPH NO DUPES

# %%
#CHANGE
str_len = 4
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
og_ending = ".ttl"
new_ending = ".nq"
min_version = 1
max_version = 10

#CHANGE
while(max_version <= 10):
    #CHANGE
    #call(["mkdir","/home/dtkhuat/results_version/random_graphs/var_version/"+str(max_version)])
    
    for file_num in range(0,1):
        #CHANGE
        path = "/home/dtkhuat/results/random_graphs/var_num_edges/" + str(num_edges) + "/"
        #path_v = "/home/dtkhuat/results_version/random_graphs/var_version/" + str(max_version) + "/" + "random_" + str(num_node_labels) + "_" + str(num_edge_labels) + "_" + str(num_edges) + "_" +str(file_num) + "_" +str(min_version) + "_" +str(max_version)
        path_v = "/home/dtkhuat/tests/test1"
        g = Graph()
        g.parse(path + "random_" + str(num_node_labels) + "_" + str(num_edge_labels) + "_" + str(num_edges) + "_" +str(file_num) + og_ending, format='ttl')
        line_counter = 0
        for subject, predicate, object in g:
            #print(subject.replace("file://"+path, ""), predicate.replace("file://"+path, ""), object.replace("file://"+path, ""))
            s = subject.replace("file://"+path, "")
            p = predicate.replace("file://"+path, "")
            o = object.replace("file://"+path, "")
            start = random.randint(min_version,max_version)
            end = random.randint(start,max_version)
            
            
            write_hyperedge(path_v,[s, p, o], start, end)
            line_counter = line_counter + 1
            extender = random.random()
            '''
            while(extender < 0.1 and end < (max_version-1) and line_counter < num_edges):
                start = random.randint(end+2,max_version)
                end = random.randint(start,max_version)
                write_hyperedge(path_v,[s, p, o], start, end)
                line_counter = line_counter + 1
                extender = random.random()
            '''
            #CHANGE
            if(line_counter >= num_edges):
                break
    
        
    #CHANGE
    max_version = max_version + 10

# %%
#part = "11"
path_1 = "/home/dtkhuat/tests/test2"
path_2 = "/home/dtkhuat/tests/test1"

line_counter = 0
prev_line = ""
bla_counter = 0
with open(path_1, 'a') as file_1, open(path_2, 'r') as file_2:
    
    '''
    if line_counter == 500000:
        file_1.close()
        file_2.close()
    '''
    for line in file_2:
        if len(line) > 4000:
            continue
        if not line.isascii():
            continue
        if line_counter == 0 :
            file_1.write(line)
            
        '''
        if "\\t\\t" in line:
            print("hi")
            line = line.replace("\\t\\t", "\\ty\\t")
        '''
        if line_counter > 0:
            if prev_line == line:
                bla_counter = bla_counter +1
                continue
            else:
                file_1.write(line)
        line_counter = line_counter + 1
        prev_line = line
print(bla_counter)
# Out:
# 0
