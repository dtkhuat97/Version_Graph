# %%
from subprocess import call
import csv
import os
import numpy as np
import matplotlib.pyplot as plt
import statistics

# %% [markdown]
# #PLOT C RATE FOR MAXIMUM LABEL SIZE

# %%
'''
path = "/home/dtkhuat/results_version/random_graphs/var_edge_len/"
str_len = 4
increment = 4
c_size = []
original = []
ir_c = []
ie_c = []
date = "18_06_2024"
while str_len < 65:
    temp = []
    temp2 = []
    temp3 = []
    with open(path+str(str_len)+"/"+date+'.csv', 'r') as csv_file:
        csvreader = csv.reader(csv_file)
        for row in csvreader:
            temp.append(float(row[1]))
            temp2.append(float(row[2]))
            temp3.append(float(row[3]))
    original.append(temp)
    ir_c.append(temp2)
    ie_c.append(temp3)
    str_len = str_len + increment

fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Maximum label size of node and edges")
plt.ylabel("Compression ratio")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x = []
y = []

for i in range(0,16):
    y.append(statistics.mean(ir_c[i])/statistics.mean(original[i]))
    x.append((i+1)*4-0.5)
bp = ax.bar(x, y, linewidth=2, capsize=6)

plt.savefig("/home/dtkhuat/results_version/plots/c_rate/ir_var_edge_len.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()

fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Maximum label size of node and edges")
plt.ylabel("Compression ratio")

x = []
y = []

for i in range(0,16):
    y.append(statistics.mean(ie_c[i])/statistics.mean(original[i]))
    x.append((i+1)*4+0.5)
bp = ax.bar(x, y, linewidth=2, capsize=6)
#plt.savefig("/home/dtkhuat/results_version/plots/c_rate/iv_var_edge_len.pdf", format="pdf", bbox_inches="tight")
plt.savefig("/home/dtkhuat/plots/test2/iv_var_edge_len.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()
'''

path = "/home/dtkhuat/results_version/random_graphs/var_edge_len/"
str_len = 4
increment = 4
c_size = []
original = []
ir_c = []
ie_c = []
date = "18_06_2024"
while str_len < 65:
    temp = []
    temp2 = []
    temp3 = []
    with open(path+str(str_len)+"/"+date+'.csv', 'r') as csv_file:
        csvreader = csv.reader(csv_file)
        for row in csvreader:
            temp.append(float(row[1]))
            temp2.append(float(row[2]))
            temp3.append(float(row[3]))
    original.append(temp)
    ir_c.append(temp2)
    ie_c.append(temp3)
    str_len = str_len + increment

fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Maximum label size of node and edges")
plt.ylabel("Compression ratio")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x = []
y = []

for i in range(0,16):
    y.append(statistics.mean(ir_c[i])/statistics.mean(original[i]))
    x.append((i+1)*4-0.5)
bp = ax.bar(x, y, linewidth=2, capsize=6)

plt.savefig("/home/dtkhuat/results_version/plots/c_rate/ir_var_edge_len.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()

fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Maximum label size of node and edges")
plt.ylabel("Compression ratio")

x = []
y = []

for i in range(0,16):
    y.append(statistics.mean(ie_c[i])/statistics.mean(original[i]))
    x.append((i+1)*4+0.5)
bp = ax.bar(x, y, linewidth=2, capsize=6)
#plt.savefig("/home/dtkhuat/results_version/plots/c_rate/iv_var_edge_len.pdf", format="pdf", bbox_inches="tight")
plt.savefig("/home/dtkhuat/plots/test2/iv_var_edge_len.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()

# %% [markdown]
# ##PLOT CRATE FOR NUM NODES

# %%
path = "/home/dtkhuat/results_version/random_graphs/var_num_nodes/"
num_nodes = 1000
increment = 1000
original = []
ir_c = []
ie_c = []
date = "18_06_2024"
while num_nodes <= 10000:
    temp = []
    temp2 = []
    temp3 = []
    with open(path+str(num_nodes)+"/"+date+'.csv', 'r') as csv_file:
        csvreader = csv.reader(csv_file)
        for row in csvreader:
            temp.append(float(row[1]))
            temp2.append(float(row[2]))
            temp3.append(float(row[3]))
    original.append(temp)
    ir_c.append(temp2)
    ie_c.append(temp3)
    num_nodes = num_nodes + increment

print(np.asarray(original).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Nodes")
plt.ylabel("Compression ratio")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x = []
y = []

for i in range(0,10):
    y.append(statistics.mean(ir_c[i])/statistics.mean(original[i]))
    x.append((i+1)*1000 - 125)
bp = ax.bar(x, y, width = 250)
'''
plt.savefig("/home/dtkhuat/results_version/plots/c_rate/ir_var_num_nodes.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()

fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Nodes")
plt.ylabel("Compression ratio")
'''
x = []
y = []

for i in range(0,10):
    y.append(statistics.mean(ie_c[i])/statistics.mean(original[i]))
    x.append((i+1)*1000 + 125)
bp = ax.bar(x, y, width = 250)
#plt.savefig("/home/dtkhuat/results_version/plots/c_rate/iv_var_num_nodes.pdf", format="pdf", bbox_inches="tight")
plt.savefig("/home/dtkhuat/plots/test2/iv_var_num_nodes.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()
# Out:
# (10, 100)

# %% [markdown]
# ##PLOT CRATE NUMBER OF EDGES

# %%
path = "/home/dtkhuat/results_version/random_graphs/var_num_edges/"
num_edges = 1000
increment = 1000
original = []
ir_c = []
ie_c = []
date = "18_06_2024"
while num_edges <= 10000:
    temp = []
    temp2 = []
    temp3 = []
    with open(path+str(num_edges)+"/"+date+'.csv', 'r') as csv_file:
        csvreader = csv.reader(csv_file)
        for row in csvreader:
            temp.append(float(row[1]))
            temp2.append(float(row[2]))
            temp3.append(float(row[3]))
    original.append(temp)
    ir_c.append(temp2)
    ie_c.append(temp3)
    num_edges = num_edges + increment

print(np.asarray(original).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Edges")
plt.ylabel("Compression ratio")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x = []
y = []

for i in range(0,10):
    y.append(statistics.mean(ir_c[i])/statistics.mean(original[i]))
    x.append((i+1)*1000 - 125)
bp = ax.bar(x, y, width = 250)
'''
plt.savefig("/home/dtkhuat/results_version/plots/c_rate/ir_var_num_edges.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()

fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Edges")
plt.ylabel("Compression ratio")
'''
x = []
y = []

for i in range(0,10):
    y.append(statistics.mean(ie_c[i])/statistics.mean(original[i]))
    x.append((i+1)*1000 + 125)
bp = ax.bar(x, y, width = 250)
#plt.savefig("/home/dtkhuat/results_version/plots/c_rate/iv_var_num_edges.pdf", format="pdf", bbox_inches="tight")
plt.savefig("/home/dtkhuat/plots/test2/iv_var_num_edges.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()
# Out:
# (10, 100)

# %%
#PLOT CRATE NUM VERSION

# %%
path = "/home/dtkhuat/results_version/random_graphs/var_version/"
max_version = 10
increment = 10
original = []
ir_c = []
ie_c = []
date="18_06_2024"
while max_version <= 100:
    temp = []
    temp2 = []
    temp3 = []
    with open(path+str(max_version)+"/"+date+'.csv', 'r') as csv_file:
        csvreader = csv.reader(csv_file)
        for row in csvreader:
            temp.append(float(row[1]))
            temp2.append(float(row[2]))
            temp3.append(float(row[3]))
    original.append(temp)
    ir_c.append(temp2)
    ie_c.append(temp3)
    max_version = max_version + increment

#print(ir_c)
#print(ie_c)
print(np.asarray(original).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Maximum Number of Versions")
plt.ylabel("Compression ratio")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x = []
y = []

for i in range(0,10):
    y.append(statistics.mean(ir_c[i])/statistics.mean(original[i]))
    x.append((i+1)*10-2)
bp = ax.bar(x, y, linewidth=4, capsize=6, width = 5)
'''
print(x)
plt.savefig("/home/dtkhuat/results_version/plots/c_rate/ir_var_version.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()

fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Maximum Number of Versions")
plt.ylabel("Compression ratio")
'''
x = []
y = []

for i in range(0,10):
    y.append(statistics.mean(ie_c[i])/statistics.mean(original[i]))
    x.append((i+1)*10+2)
bp = ax.bar(x, y, linewidth=4, capsize=6, width = 5)
#plt.savefig("/home/dtkhuat/results_version/plots/c_rate/iv_var_version.pdf", format="pdf", bbox_inches="tight")
plt.savefig("/home/dtkhuat/plots/test2/iv_var_version.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()
# Out:
# (10, 100)

# %% [markdown]
# #PLOT REAL GRAPHS

# %%
path = "/home/dtkhuat/results_version/size_real_18_06_2024.csv"

original = []
ir_c = []
ie_c = []
x = []
y = []
date = "18_06_2024"
with open(path, 'r') as csv_file:
    csvreader = csv.reader(csv_file)
    #next(csvreader, None) 
    for row in csvreader:
        x.append(row[0])
        original.append(float(row[1]))
        ir_c.append(float(row[2]))
        ie_c.append(float(row[3]))

#x=x[:-1]
print(np.asarray(original).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression ratio")

print(x)
y = []
for i in range(1,11):
    y.append(ir_c[i-1]/original[i-1])
bp = ax.bar(x, y)
plt.xticks(rotation=90)
plt.savefig("/home/dtkhuat/results_version/plots/c_rate/real_ir_c_rate.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()

fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression ratio")

y = []
for i in range(1,11):
    y.append(ie_c[i-1]/original[i-1])
bp = ax.bar(x, y)
plt.xticks(rotation=90)
plt.savefig("/home/dtkhuat/results_version/plots/c_rate/real_iv_c_rate.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()
# Out:
# (10,)
# ['allData_p1', 'allData_p2', 'allData_p3', 'allData_p4', 'allData_p5', 'allData_p6', 'allData_p7', 'allData_p8', 'allData_p9', 'allData_p10']

# %% [markdown]
# ##PLOT C RATE SEMI REAL GRAPHS

# %%
path = "/home/dtkhuat/results_version/size_semi_real_18_06_2024.csv"

original = []
ir_c = []
ie_c = []
x = []
y = []
date = "18_06_2024"
with open(path, 'r') as csv_file:
    csvreader = csv.reader(csv_file)
    #next(csvreader, None) 
    for row in csvreader:
        #x.append(row[0])
        original.append(float(row[1]))
        ir_c.append(float(row[2]))
        ie_c.append(float(row[3]))

print(ir_c)
print(len(ir_c))
print(np.asarray(original).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression ratio")

x = ["export", "homepages_en","persondate_en", "taxonomy", "jamendo", "lubm-10"]
for i in range(0,6):
    y.append(statistics.mean(ir_c[i*5:i*5+5])/statistics.mean(original[i*5:i*5+5]))

bp = ax.bar(x, y)
plt.xticks(rotation=90)
plt.savefig("/home/dtkhuat/results_version/plots/semi_real_graphs_ir_c_rate.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()

fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression ratio")

y = []
for i in range(0,6):
    y.append(statistics.mean(ie_c[i*5:i*5+5])/statistics.mean(original[i*5:i*5+5]))
bp = ax.bar(x, y)
plt.xticks(rotation=90)
plt.savefig("/home/dtkhuat/results_version/plots/semi_real_graphs_iv_c_rate5.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()
# Out:
# [369229.0, 365043.0, 371044.0, 365076.0, 367534.0, 1549579.0, 1546227.0, 1545092.0, 1544719.0, 1544062.0, 599323.0, 598373.0, 594453.0, 596145.0, 595639.0, 10485660.0, 10487141.0, 10482561.0, 10494249.0, 10497021.0, 14739438.0, 14707354.0, 14624282.0, 14719482.0, 14570205.0, 11598730.0, 11774887.0, 11582040.0, 11816114.0, 11721593.0]
# 30
# (30,)

# %% [markdown]
# Only get values - no plot

# %%
path = "/home/dtkhuat/results_version/size_semi_real_18_06_2024.csv"

original = []
ir_c = []
ie_c = []
x = []
y = []
date = "18_06_2024"
with open(path, 'r') as csv_file:
    csvreader = csv.reader(csv_file)
    #next(csvreader, None) 
    for row in csvreader:
        #x.append(row[0])
        original.append(float(row[1]))
        ir_c.append(float(row[2]))
        ie_c.append(float(row[3]))

#print(ir_c)
#print(len(ir_c))
#print(np.asarray(original).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression ratio")

x = ["export", "homepages_en","persondate_en", "taxonomy", "jamendo", "lubm-10"]
for i in range(0,6):
    y.append(statistics.mean(ir_c[i*5:i*5+5])/statistics.mean(original[i*5:i*5+5]))
print(y)

y = []
for i in range(0,6):
    y.append(statistics.mean(ie_c[i*5:i*5+5])/statistics.mean(original[i*5:i*5+5]))
# Out:
# [0.10646688396131147, 0.24873221748220545, 0.10763514646355776, 0.10772579528874267, 0.09897654056898378, 0.05132733056597619]

# %%
file_name = "lubm-10"
ending = ".ttl"
path_og = "/home/dtkhuat/eval_datasets/" + file_name + ending
path_itr = "/home/dtkhuat/results_version/itr2/semi_real_graphs_compressed/"+file_name + "_compressed"
print(os.stat(path_itr).st_size/os.stat(path_og).st_size)
# Out:
# 0.03609157809056049

# %%
path = "/home/dtkhuat/results_version/size_real_18_06_2024.csv"

original = []
ir_c = []
ie_c = []
x = []
y = []
date = "18_06_2024"
with open(path, 'r') as csv_file:
    csvreader = csv.reader(csv_file)
    #next(csvreader, None) 
    for row in csvreader:
        x.append(row[0])
        original.append(float(row[1]))
        ir_c.append(float(row[2]))
        ie_c.append(float(row[3]))

#print(x)
y = []
for i in range(1,11):
    y.append(ir_c[i-1]/original[i-1])

print(y)
# Out:
# [0.06369318042650553, 0.05966361270661304, 0.05212365150524917, 0.06374931557827462, 0.06620282073352193, 0.054453565872958236, 0.051825698224514584, 0.048318430766736274, 0.04882315884479686, 0.04815165709999063]

# %% [markdown]
# GET C RATE REAL ITR WITH VERSION

# %%
path_size = "/home/dtkhuat/version_values/temp"

for i in range(1,11):
        researched = str(i)
        path_og = "/home/dtkhuat/preprocessed_files/final_itr_no_dupes/allData_p"+ researched
        path_incidence = "/home/dtkhuat/results_version/itr2/real_graphs_compressed/allData_p"+researched + "_compressed2"
        with open(path_size+'.csv', 'a') as csv_file:
                fields = ["allData_p"+researched, os.stat(path_og).st_size, os.stat(path_incidence).st_size]
                csv_writer = csv.writer(csv_file, delimiter=',')
                csv_writer.writerow(fields)

# %%
path = "/home/dtkhuat/version_values/temp.csv"

original = []
ir_c = []
ie_c = []
x = []
y = []
#date = "18_06_2024"
with open(path, 'r') as csv_file:
    csvreader = csv.reader(csv_file)
    #next(csvreader, None) 
    for row in csvreader:
        x.append(row[0])
        original.append(float(row[1]))
        ir_c.append(float(row[2]))
        ie_c.append(float(row[3]))

print(x)
y = []
for i in range(1,11):
    #y.append(ir_c[i-1]/original[i-1])
    print(ir_c[i-1]/original[i-1])
    print(ie_c[i-1]/original[i-1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 16
#      14         original.append(float(row[1]))
#      15         ir_c.append(float(row[2]))
# ---> 16         ie_c.append(float(row[3]))
#      18 print(x)
#      19 y = []
#
# IndexError: list index out of range

# %%
path = "/home/dtkhuat/index_values/sizes/21_04_24.csv"

original = []
ir_c = []
ie_c = []
x = []
y = []
#date = "18_06_2024"
with open(path, 'r') as csv_file:
    csvreader = csv.reader(csv_file)
    next(csvreader, None)  
    for row in csvreader:
        x.append(row[0])
        original.append(float(row[1]))
        ir_c.append(float(row[2]))
        ie_c.append(float(row[3]))

print(x)
y_index = []
y_itr = []
for i in range(0,len(ir_c)):
    y_itr.append(ir_c[i]/original[i])
    y_index.append(ie_c[i]/original[i])
print(original, len(original))
print(ir_c, len(ir_c))
print(ie_c, len(ie_c))

path_size = "/home/dtkhuat/index_values/sizes/real_18_07_2024"

for i in range(0, len(y_itr)):
        with open(path_size+'.csv', 'a') as csv_file:
                fields = [x[i], y_itr[i], y_index[i]]
                csv_writer = csv.writer(csv_file, delimiter=',')
                csv_writer.writerow(fields)
# Out:
# ['jamendo.nt', 'archiveshub.nt', 'export.nq', 'homepages_en.ttl', 'scholarydata_dump.nt', 'lubm-10.ttl', 'geo-coordinates_lang=en.ttl', 'long-abstracts_lang=eu_uris=en.ttl', 'instance_types_en.ttl', 'taxonomy.ttl', 'bag-transformed.nt', 'ontology.nt', 'dnb_set=authorities_partition=werk.nt']
# [147103035.0, 243700760.0, 3975451.0, 6080545.0, 225455038.0, 176638494.0, 735704210.0, 389421973.0, 748695271.0, 94715167.0, 172888674.0, 870959552.0, 902832540.0] 13
# [14697659.0, 14352384.0, 425512.0, 2505413.0, 8246666.0, 10923615.0, 93679941.0, 70161532.0, 156252782.0, 2254522.0, 18968180.0, 89580291.0, 110611793.0] 13
# [18107135.0, 20638836.0, 487418.0, 2781777.0, 13391044.0, 15035248.0, 98591091.0, 76223596.0, 52633600.0, 2368818.0, 20738108.0, 102456147.0, 128330619.0] 13

# %%
path = "/home/dtkhuat/results_version/random_graphs/var_num_edges/"
num_edges = 1000
increment = 1000
original = []
ir_c = []
ie_c = []
date = "18_06_2024"
while num_edges <= 10000:
    temp = []
    temp2 = []
    temp3 = []
    with open(path+str(num_edges)+"/"+date+'.csv', 'r') as csv_file:
        csvreader = csv.reader(csv_file)
        for row in csvreader:
            temp.append(float(row[1]))
            temp2.append(float(row[2]))
            temp3.append(float(row[3]))
    original.append(temp)
    ir_c.append(temp2)
    ie_c.append(temp3)
    num_edges = num_edges + increment

print(np.asarray(original).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Edges")
plt.ylabel("Compression ratio")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x = []
y = []

for i in range(0,10):
    y.append(statistics.mean(ir_c[i])/statistics.mean(original[i]))
    x.append((i+1)*1000 - 125)
bp = ax.bar(x, y, width = 250)
'''
plt.savefig("/home/dtkhuat/results_version/plots/c_rate/ir_var_num_edges.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()

fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Edges")
plt.ylabel("Compression ratio")
'''
x = []
y = []

for i in range(0,10):
    y.append(statistics.mean(ie_c[i])/statistics.mean(original[i]))
    x.append((i+1)*1000 + 125)
bp = ax.bar(x, y, width = 250)
#plt.savefig("/home/dtkhuat/results_version/plots/c_rate/iv_var_num_edges.pdf", format="pdf", bbox_inches="tight")
plt.savefig("/home/dtkhuat/plots/test2/bla.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()
# Out:
# (10, 100)

# %%
path_version_compressed = "/home/dtkhuat/results_version/version_itr/real_graphs_compressed/"
path_version_og = "/home/dtkhuat/preprocessed_files/final2/"

file_name = "allData_p"
size_version_compressed = []
size_version_og = []
c_rate_version = []
for i in range(1,11):
    size_a = os.stat(path_version_compressed+file_name+str(i)+"_compressed").st_size
    size_b = os.stat(path_version_og+file_name+str(i)).st_size
    c_rate_version.append(size_a/size_b)

print(c_rate_version)

path_itr_compressed = "/home/dtkhuat/results_version/itr2/real_graphs_compressed/"
path_itr_og = "/home/dtkhuat/preprocessed_files/final_itr_dupes/"

file_name = "allData_p"
size_version_compressed = []
size_version_og = []
c_rate_itr = []
for i in range(1,11):
    size_a = os.stat(path_itr_compressed+file_name+str(i)+"_compressed2").st_size
    size_b = os.stat(path_itr_og+file_name+str(i)).st_size
    c_rate_itr.append(size_a/size_b)

print(c_rate_itr)

#print(np.asarray(original).shape)
fig = plt.figure(figsize =(5, 2.65))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression ratio")

x = []
y = []
for i in range(0,10):
    y.append(c_rate_itr[i])
    x.append((i+1)*1000 - 125)
bp = ax.bar(x, y, width = 250, label = "ITR on RDF Graphs")

x = []
y = []

for i in range(0,10):
    y.append(c_rate_version[i])
    x.append((i+1)*1000 + 125)
bp = ax.bar(x, y, width = 250, label = "ITR on Version Graphs")


plt.xticks(x,rotation=20, ha = "right")

plt.legend(loc="upper right")
plt.xticks(np.arange(0, 10001, step=1000))
plt.yticks(np.arange(0, 1.1, step=0.1))
label = []
for i in range(1,11):
    label.append("allData_p" + str(i))
ax.set_xticks(x, labels=label)

plt.savefig("/home/dtkhuat/plots/version/replacement_real_version_cr3.pdf", format="pdf", bbox_inches="tight")
plt.show()
# Out:
# [0.08636123197522286, 0.081538046205131, 0.060934479977314555, 0.0776107245810247, 0.08710817721364351, 0.055202727765873615, 0.05242606397066012, 0.04886664250734841, 0.05006601105334343, 0.049288997374425735]
# [0.05477131847112803, 0.0501412546982499, 0.029372148095751102, 0.03849280334881451, 0.04887106242420286, 0.0212580657236543, 0.019902475030709986, 0.019708996433496283, 0.018905382328792554, 0.01958869085441175]
