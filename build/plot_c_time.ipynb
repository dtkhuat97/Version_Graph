# %%
#PLOT C TIME

# %%
from subprocess import call
import csv
import os
import numpy as np
import matplotlib.pyplot as plt
import statistics

# %%
path = "/home/dtkhuat/results_version/itr2/times/var_num_edges/"
timings = []
date = "17_07_2024"
with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
#fig = plt.figure(figsize =(5, 5))
#fig=plt.figure()  
fig = plt.figure(figsize =(5, 3))
ax = fig.add_axes([0, 0, 1, 1])

plt.xlabel("Number of Edges")
plt.ylabel("Compression time in seconds")

#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*1000)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.plot(x, y, linestyle='-', marker='o' , label = "ITR on RDF Graphs")

path = "/home/dtkhuat/results_version/version_itr/times/var_num_edges/"
timings = []
date = "18_06_2024"

with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)
'''
print(np.asarray(timings).shape)
#fig = plt.figure(figsize =(5, 5))
fig=plt.figure()  
ax = fig.add_axes([0, 0, 1, 1])

plt.xlabel("Number of Edges")
plt.ylabel("Compression time in seconds")
'''
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*1000)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.plot(x, y, linestyle='-', marker='o' , label = "ITR on Version Graphs")

plt.legend(loc="upper left")
plt.xticks(np.arange(0, 10001, step=1000))
plt.yticks(np.arange(0, 1.1, step=0.1))
plt.savefig("/home/dtkhuat/plots/version/ct_var_num_edges.pdf", format="pdf", bbox_inches="tight")
plt.show()
#plt.savefig("/home/dtkhuat/results_version/plots/c_time/IR_var_num_edges5.pdf", format="pdf", bbox_inches="tight")
# Out:
# (10, 100)

# %% [markdown]
# ## PLT TIME EDGE lABEL LEN

# %%
path = "/home/dtkhuat/results_version/itr2/times/var_edge_len/"
timings = []
date = "17_07_2024"
with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
#fig = plt.figure(figsize =(5, 5))
#fig=plt.figure()  
fig = plt.figure(figsize =(5, 3))
ax = fig.add_axes([0, 0, 1, 1])

plt.xlabel("Maximum Length of Node and Edge Labels")
plt.ylabel("Compression time in seconds")

#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,16):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*4)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.plot(x, y, linestyle='-', marker='o' , label = "ITR on RDF Graphs")

path = "/home/dtkhuat/results_version/version_itr/times/var_edge_len/"
timings = []
date = "18_06_2024"

with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)
'''
print(np.asarray(timings).shape)
#fig = plt.figure(figsize =(5, 5))
fig=plt.figure()  
ax = fig.add_axes([0, 0, 1, 1])

plt.xlabel("Number of Edges")
plt.ylabel("Compression time in seconds")
'''
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,16):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*4)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.plot(x, y, linestyle='-', marker='o' , label = "ITR on Version Graphs")

plt.legend(loc="upper left")
plt.xticks(np.arange(0, 65, step=4))
plt.yticks(np.arange(0, 0.051, step=0.01))
plt.savefig("/home/dtkhuat/plots/version/ct_var_edge_len2.pdf", format="pdf", bbox_inches="tight")
plt.show()
#plt.savefig("/home/dtkhuat/results_version/plots/c_time/IR_var_num_edges5.pdf", format="pdf", bbox_inches="tight")
'''
path = "/home/dtkhuat/results_version/itr/times/var_num_nodes/"
timings = []
date = "18_06_2024"
with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Nodes")
plt.ylabel("Compression time in seconds")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*1000)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.savefig("/home/dtkhuat/results_version/plots/c_time/IR_var_num_nodes.pdf", format="pdf", bbox_inches="tight")
'''
# Out:
# (16, 100)
# '\npath = "/home/dtkhuat/results_version/itr/times/var_num_nodes/"\ntimings = []\ndate = "18_06_2024"\nwith open(path+date+\'.csv\', \'r\') as csv_file:\n    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)\n    for row in csvreader:\n        timings.append(row)\n\nprint(np.asarray(timings).shape)\nfig = plt.figure(figsize =(5, 5))\nax = fig.add_axes([0, 0, 1, 1])\nplt.xlabel("Number of Nodes")\nplt.ylabel("Compression time in seconds")\n#bp = ax.stem(timings,showfliers=False,showmeans=True)\nx_error = []\ny_error = []\nx = []\ny = []\nfor i in range(0,10):\n    y.append(statistics.mean(timings[i]))\n    x.append((i+1)*1000)\n    x_error.append(max(timings[i])-y[i])\n    y_error.append(y[i]-min(timings[i]))\nbp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt=\'o\', linewidth=2, capsize=6)\nplt.savefig("/home/dtkhuat/results_version/plots/c_time/IR_var_num_nodes.pdf", format="pdf", bbox_inches="tight")\n'

# %% [markdown]
# ## NUM NODES

# %%
path = "/home/dtkhuat/results_version/itr2/times/var_num_nodes/"
timings = []
date = "17_07_2024"
with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
#fig = plt.figure(figsize =(5, 5))
#fig=plt.figure()  
fig = plt.figure(figsize =(5, 3))
ax = fig.add_axes([0, 0, 1, 1])

plt.xlabel("Number of Nodes")
plt.ylabel("Compression time in seconds")

#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*1000)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.plot(x, y, linestyle='-', marker='o' , label = "ITR on RDF Graphs")

path = "/home/dtkhuat/results_version/version_itr/times/var_num_nodes/"
timings = []
date = "18_06_2024"

with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)
'''
print(np.asarray(timings).shape)
#fig = plt.figure(figsize =(5, 5))
fig=plt.figure()  
ax = fig.add_axes([0, 0, 1, 1])

plt.xlabel("Number of Edges")
plt.ylabel("Compression time in seconds")
'''
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*1000)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.plot(x, y, linestyle='-', marker='o' , label = "ITR on Version Graphs")

plt.legend(loc="upper left")
plt.xticks(np.arange(0, 10001, step=1000))
plt.yticks(np.arange(0, 0.051, step=0.01))
plt.savefig("/home/dtkhuat/plots/version/ct_var_num_nodes.pdf", format="pdf", bbox_inches="tight")
plt.show()

'''
path = "/home/dtkhuat/results_version/itr/times/var_num_nodes/"
timings = []
date = "18_06_2024"
with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Maximum label size of edges and nodes")
plt.ylabel("Compression time in seconds")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,16):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*4)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
print(y)
#plt.axis([0, 70, 0, 0.01])
bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.savefig("/home/dtkhuat/results_version/plots/c_time/IR_var_edge_len.pdf", format="pdf", bbox_inches="tight")
'''
# Out:
# (10, 100)
# '\npath = "/home/dtkhuat/results_version/itr/times/var_num_nodes/"\ntimings = []\ndate = "18_06_2024"\nwith open(path+date+\'.csv\', \'r\') as csv_file:\n    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)\n    for row in csvreader:\n        timings.append(row)\n\nprint(np.asarray(timings).shape)\nfig = plt.figure(figsize =(5, 5))\nax = fig.add_axes([0, 0, 1, 1])\nplt.xlabel("Maximum label size of edges and nodes")\nplt.ylabel("Compression time in seconds")\n#bp = ax.stem(timings,showfliers=False,showmeans=True)\nx_error = []\ny_error = []\nx = []\ny = []\nfor i in range(0,16):\n    y.append(statistics.mean(timings[i]))\n    x.append((i+1)*4)\n    x_error.append(max(timings[i])-y[i])\n    y_error.append(y[i]-min(timings[i]))\nprint(y)\n#plt.axis([0, 70, 0, 0.01])\nbp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt=\'o\', linewidth=2, capsize=6)\nplt.savefig("/home/dtkhuat/results_version/plots/c_time/IR_var_edge_len.pdf", format="pdf", bbox_inches="tight")\n'

# %% [markdown]
# ## IR PLOT CTIME NUM VERSIOn

# %%
path = "/home/dtkhuat/results_version/itr2/times/var_version/"
timings = []
date = "17_07_2024"
with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
#fig = plt.figure(figsize =(5, 5))
#fig=plt.figure()  
fig = plt.figure(figsize =(5, 3))
ax = fig.add_axes([0, 0, 1, 1])

plt.xlabel("Number of Versions")
plt.ylabel("Compression time in seconds")

#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*10)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.plot(x, y, linestyle='-', marker='o' , label = "ITR on RDF Graphs")

path = "/home/dtkhuat/results_version/version_itr/times/var_version/"
timings = []
date = "18_06_2024"

with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)
'''
print(np.asarray(timings).shape)
#fig = plt.figure(figsize =(5, 5))
fig=plt.figure()  
ax = fig.add_axes([0, 0, 1, 1])

plt.xlabel("Number of Edges")
plt.ylabel("Compression time in seconds")
'''
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*10)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.plot(x, y, linestyle='-', marker='o' , label = "ITR on Version Graphs")

plt.legend(loc="upper left")
plt.xticks(np.arange(0, 101, step=10))
plt.yticks(np.arange(0, 0.051, step=0.01))
plt.savefig("/home/dtkhuat/plots/version/ct_var_num_version.pdf", format="pdf", bbox_inches="tight")
plt.show()
'''
path = "/home/dtkhuat/results_version/itr/times/var_version/"
timings = []
date = "18_06_2024"
with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Maximum Number of Versions")
plt.ylabel("Compression time in seconds")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*10)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.savefig("/home/dtkhuat/results_version/plots/c_time/IR_var_version.pdf", format="pdf", bbox_inches="tight")
'''
# Out:
# (10, 100)
# '\npath = "/home/dtkhuat/results_version/itr/times/var_version/"\ntimings = []\ndate = "18_06_2024"\nwith open(path+date+\'.csv\', \'r\') as csv_file:\n    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)\n    for row in csvreader:\n        timings.append(row)\n\nprint(np.asarray(timings).shape)\nfig = plt.figure(figsize =(5, 5))\nax = fig.add_axes([0, 0, 1, 1])\nplt.xlabel("Maximum Number of Versions")\nplt.ylabel("Compression time in seconds")\n#bp = ax.stem(timings,showfliers=False,showmeans=True)\nx_error = []\ny_error = []\nx = []\ny = []\nfor i in range(0,10):\n    y.append(statistics.mean(timings[i]))\n    x.append((i+1)*10)\n    x_error.append(max(timings[i])-y[i])\n    y_error.append(y[i]-min(timings[i]))\nbp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt=\'o\', linewidth=2, capsize=6)\nplt.savefig("/home/dtkhuat/results_version/plots/c_time/IR_var_version.pdf", format="pdf", bbox_inches="tight")\n'

# %% [markdown]
# ##GET TIMING NUM NODES

# %%
path = "/home/dtkhuat/results_version/version_itr/times/var_num_nodes/"
timings = []
date = "18_06_2024"
with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Nodes")
plt.ylabel("Compression time in seconds")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*1000)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#plt.axis([0, 12000, 0, 0.01])
bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.savefig("/home/dtkhuat/results_version/plots/c_time/IV_var_num_nodes.pdf", format="pdf", bbox_inches="tight")
# Out:
# (10, 100)

# %% [markdown]
# ##GET TIMING NUM EDGE LABELS

# %%
path = "/home/dtkhuat/results_version/version_itr/times/var_edge_len/"
timings = []
date = "18_06_2024"
with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Edge Labels")
plt.ylabel("Compression time in seconds")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,16):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*4)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#plt.axis([0, 12000, 0, 0.01])
bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.savefig("/home/dtkhuat/results_version/plots/c_time/IV_var_edge_len.pdf", format="pdf", bbox_inches="tight")
# Out:
# (16, 100)

# %% [markdown]
# ##GET TIMING NUM EDGES

# %%
path = "/home/dtkhuat/results_version/version_itr/times/var_num_edges/"
timings = []
date = "18_06_2024"
with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Number of Edges")
plt.ylabel("Compression time in seconds")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*1000)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#plt.axis([0, 12000, 0, 0.01])
bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.savefig("/home/dtkhuat/results_version/plots/c_time/IV_var_num_edges.pdf", format="pdf", bbox_inches="tight")
# Out:
# (10, 100)

# %% [markdown]
# #GET TIMING VAR VERSION

# %%
path = "/home/dtkhuat/results_version/version_itr/times/var_version/"
timings = []
date = "18_06_2024"
with open(path+date+'.csv', 'r') as csv_file:
    csvreader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC)
    for row in csvreader:
        timings.append(row)

print(np.asarray(timings).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("Maximum Number of Versions")
plt.ylabel("Compression time in seconds")
#bp = ax.stem(timings,showfliers=False,showmeans=True)
x_error = []
y_error = []
x = []
y = []
for i in range(0,10):
    y.append(statistics.mean(timings[i]))
    x.append((i+1)*10)
    x_error.append(max(timings[i])-y[i])
    y_error.append(y[i]-min(timings[i]))
#plt.axis([0, 12000, 0, 0.01])
bp = ax.errorbar(x, y, yerr = y_error,xerr = x_error, fmt='o', linewidth=2, capsize=6)
plt.savefig("/home/dtkhuat/results_version/plots/c_time/IV_var_version.pdf", format="pdf", bbox_inches="tight")
# Out:
# (10, 100)

# %% [markdown]
# ##PLOT CTIME REAL GRAPHS

# %%
'''
path = "/home/dtkhuat/results_version/real_18_06_2024.csv"

original = []
ir_c = []
ie_c = []
x = []
y = []
date = "18_06_2024"
with open(path, 'r') as csv_file:
    csvreader = csv.reader(csv_file)
    #next(csvreader, None) 
    for row in csvreader:
        x.append(row[0])
        #original.append(float(row[1]))
        ir_c.append(float(row[1]))
        ie_c.append(float(row[2]))


print(np.asarray(original).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression time")

#x = ["export", "homepages_en","persondate_en", "taxonomy", "jamendo", "lubm-10"]

for i in range(0,10):
    y.append(ir_c)

for i in range(0,10):
    y.append(ir_c[i])
bp = ax.bar(x, y)
plt.xticks(rotation=90)
plt.savefig("/home/dtkhuat/results_version/plots/real_graphs_ir_c_time.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()

fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression time")

y = []
for i in range(0,10):
    y.append(ie_c[i])
bp = ax.bar(x, y)

plt.xticks(rotation=90)
plt.savefig("/home/dtkhuat/results_version/plots/real_graphs_iv_c_time.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()
'''
path = "/home/dtkhuat/version_values/timing/real_17_07_2024.csv"

original = []
c_time_itr = []
c_time_v = []
x = []
y = []
date = "18_06_2024"
with open(path, 'r') as csv_file:
    csvreader = csv.reader(csv_file)
    #next(csvreader, None) 
    for row in csvreader:
        x.append(row[0])
        #original.append(float(row[1]))
        c_time_itr.append(float(row[1]))
        c_time_v.append(float(row[2]))

print(c_time_itr, c_time_v)
label = []
for i in range(1,11):
    label.append("allData_p" + str(i))
#x_version = np.arange(0,51,step=5)
print(label)


fig = plt.figure(figsize =(5, 2.65))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression time in seconds")

x = np.arange(0,50,step=5)
plt.yticks(np.arange(0, 10000, step=1000))
plt.plot(x, c_time_itr, linestyle='-', marker='o' , label = "ITR on RDF Graphs")
plt.plot(x, c_time_v, linestyle='-', marker='o' , label = "ITR on Version Graphs")
ax.set_xticks(x, labels=label)
plt.xticks(x,rotation=20, ha = "right")
plt.legend(loc="upper right")
plt.savefig("/home/dtkhuat/plots/version/replacement_ct_real3.pdf", format="pdf", bbox_inches="tight")
plt.show()
# Out:
# [11.728361, 5.877436, 33.317787, 46.709942, 19.60797, 17.912022, 19.2187, 18.773465, 18.428089, 16.406641] [405.383075, 266.304645, 8496.294794, 8515.986994, 3118.663505, 485.27344, 435.575096, 537.599113, 471.485781, 363.527494]
# ['allData_p1', 'allData_p2', 'allData_p3', 'allData_p4', 'allData_p5', 'allData_p6', 'allData_p7', 'allData_p8', 'allData_p9', 'allData_p10']

# %%
path = "/home/dtkhuat/results_version/semi_real_18_06_2024.csv"

original = []
ir_c = []
ie_c = []
x = []
y = []
date = "18_06_2024"
with open(path, 'r') as csv_file:
    csvreader = csv.reader(csv_file)
    #next(csvreader, None) 
    for row in csvreader:
        #x.append(row[0])
        #original.append(float(row[1]))
        ir_c.append(float(row[1]))
        ie_c.append(float(row[2]))

print(ir_c)
print(len(ir_c))
print(np.asarray(original).shape)
fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression time in seconds")

x = ["export", "homepages_en","persondate_en", "taxonomy", "jamendo", "lubm-10"]
for i in range(0,6):
    print(ir_c[i*5:i*5+5])
    y.append(statistics.mean(ir_c[i*5:i*5+5]))
print(y)
'''
bp = ax.bar(x, y)
plt.xticks(rotation=90)
plt.savefig("/home/dtkhuat/results_version/plots/semi_real_graphs_ir_c_time.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()

fig = plt.figure(figsize =(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression time")

y = []
for i in range(0,6):
    y.append(statistics.mean(ir_c[i*5:i*5+5]))
bp = ax.bar(x, y)
plt.xticks(rotation=90)
plt.savefig("/home/dtkhuat/results_version/plots/semi_real_graphs_iv_c_time.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()
'''
# Out:
# [12.096168, 12.038256, 13.155311, 11.002406, 12.367894, 0.922342, 0.975976, 1.007746, 0.906005, 0.918738, 4.275515, 3.786544, 4.370202, 4.62095, 3.948905, 18.147867, 16.101298, 15.712086, 15.807506, 15.588515, 227.786435, 226.441052, 289.333254, 273.394753, 296.69914, 296.964269, 293.592701, 284.120507, 280.124809, 279.29746]
# 30
# (0,)
# [12.096168, 12.038256, 13.155311, 11.002406, 12.367894]
# [0.922342, 0.975976, 1.007746, 0.906005, 0.918738]
# [4.275515, 3.786544, 4.370202, 4.62095, 3.948905]
# [18.147867, 16.101298, 15.712086, 15.807506, 15.588515]
# [227.786435, 226.441052, 289.333254, 273.394753, 296.69914]
# [296.964269, 293.592701, 284.120507, 280.124809, 279.29746]
# [12.132007, 0.9461614, 4.2004232, 16.2714544, 262.7309268, 286.8199492]
# '\nbp = ax.bar(x, y)\nplt.xticks(rotation=90)\nplt.savefig("/home/dtkhuat/results_version/plots/semi_real_graphs_ir_c_time.pdf", format="pdf", bbox_inches="tight")\nplt.show()\nplt.close()\n\nfig = plt.figure(figsize =(5, 5))\nax = fig.add_axes([0, 0, 1, 1])\nplt.xlabel("File Name")\nplt.ylabel("Compression time")\n\ny = []\nfor i in range(0,6):\n    y.append(statistics.mean(ir_c[i*5:i*5+5]))\nbp = ax.bar(x, y)\nplt.xticks(rotation=90)\nplt.savefig("/home/dtkhuat/results_version/plots/semi_real_graphs_iv_c_time.pdf", format="pdf", bbox_inches="tight")\nplt.show()\nplt.close()\n'

# %%
label = ["export", "homepages_en","persondate_en", "taxonomy", "jamendo", "lubm-10"]
path = "/home/dtkhuat/version_values/timing/semi_real_18_07_2024.csv"

original = []
c_time_itr = []
c_time_v = []
x = []
y = []
date = "18_06_2024"
with open(path, 'r') as csv_file:
    csvreader = csv.reader(csv_file)
    #next(csvreader, None) 
    for row in csvreader:
        x.append(row[0])
        #original.append(float(row[1]))
        c_time_itr.append(float(row[1]))
        c_time_v.append(float(row[2]))

print(c_time_itr, c_time_v)
#x_version = np.arange(0,51,step=5)
print(label)


fig = plt.figure(figsize =(5, 3))
ax = fig.add_axes([0, 0, 1, 1])
plt.xlabel("File Name")
plt.ylabel("Compression time in seconds")

x = np.arange(0,30,step=5)
print(len(x))
plt.yticks(np.arange(0, 500, step=50))
plt.plot(x, c_time_itr, linestyle='-', marker='o' , label = "ITR on RDF Graphs")
plt.plot(x, c_time_v, linestyle='-', marker='o' , label = "ITR on Version Graphs")
ax.set_xticks(x, labels=label)
plt.xticks(x,rotation=25, ha = "right")
plt.legend(loc="upper left")
plt.savefig("/home/dtkhuat/plots/version/ct_semi_real.pdf", format="pdf", bbox_inches="tight")
plt.show()
# Out:
# [0.679275, 0.433264, 0.780753, 1.347959, 23.14347, 36.257493] [12.132007, 0.9461614, 4.2004232, 16.2714544, 262.7309268, 286.8199492]
# ['export', 'homepages_en', 'persondate_en', 'taxonomy', 'jamendo', 'lubm-10']
# 6
