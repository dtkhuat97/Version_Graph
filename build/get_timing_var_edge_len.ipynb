# %%
from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "18_06_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4
min_version = 1
max_version = 10

#CHANGE
increment = 4
researched_path = "var_edge_len/"

while str_len <= 64:
    #CHANGE
    researched = str(str_len)
    path_og = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    #path_incidence =  "/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_edge_len/"+researched+"/"
    path_index = "/home/dtkhuat/results_version/version_itr/random_graphs_compressed/"+researched_path +researched+"/"
    #call(["mkdir","/home/dtkhuat/results_version/random_graphs/"+researched_path+researched])
    #call(["mkdir",path_index])
    #call(["touch",path_og+date+".csv"])

    
    
    
    for i in range(0,100):
        file_name = "random_"+str(num_node_labels)+"_4_"+str(num_edges)+"_"
        compressed_name = file_name + str(i) +"_" +str(min_version)+"_" + str(max_version) +"_c"
        #call(["/home/dtkhuat/IncidenceTypeRePair/build/./cgraph-cli", "--overwrite", "--rrr", "--verbose", path_og + file_name + str(i)+".ttl",  path_incidence+compressed_name])
        call(["./cgraph-cli", "--overwrite", "--verbose","--format", "hyperedge", "--max-rank", "64" , path_og + file_name + str(i)+"_" +str(min_version)+"_" + str(max_version), path_index + compressed_name])

        '''
        with open(path_og+date+'.csv', 'a') as csv_file:
            fields = [file_name+ str(i)+".ttl", os.stat(path_og + file_name+ str(i)+".ttl").st_size, os.stat(path_incidence+compressed_name).st_size, os.stat(path_index+compressed_name).st_size]
            csv_writer = csv.writer(csv_file, delimiter=',')
            csv_writer.writerow(fields)
        '''
        if(i<99):
            with open('/home/dtkhuat/results_version/version_itr/times/'+ researched_path+ date+ '.csv', 'a') as csv_file:
               #csv_writer = csv.writer(csv_file, delimiter=',')
                csv_file.write(", ")
                csv_file.close()
            #with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+ researched_path+'/timings.csv', 'a') as csv_file:
                #csv_writer = csv.writer(csv_file, delimiter=',')
            #    csv_file.write(", ")
            #    csv_file.close()
        else:
            with open('/home/dtkhuat/results_version/version_itr/times/' + researched_path+ date+ '.csv', 'a') as csv_file:
                csv_file.write("\n")
                csv_file.close()
            #with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+ researched_path+'/timings.csv', 'a') as csv_file:
            #    csv_file.write("\n")
            #    csv_file.close()

    str_len = str_len + increment
# Out:
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_0_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_0_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5672 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_1_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_1_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5788 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_2_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_2_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5773 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_3_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_3_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5737 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_4_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_4_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5763 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_5_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_5_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5742 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_6_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_6_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5693 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_7_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_7_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5755 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_8_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_8_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5695 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_9_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_9_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5768 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_10_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_10_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5721 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_11_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_11_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5812 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_12_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_12_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5817 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_13_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_13_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5745 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_14_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_14_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5725 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_15_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_15_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5785 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_16_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_16_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5715 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_17_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_17_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5816 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_18_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_18_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5723 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_19_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_19_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5772 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_20_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_20_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5769 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_21_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_21_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5740 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_22_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_22_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5797 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_23_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_23_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5811 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_24_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_24_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5676 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_25_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_25_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5691 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_26_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_26_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5712 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_27_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_27_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5694 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_28_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_28_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5753 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_29_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_29_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5738 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_30_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_30_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5853 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_31_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_31_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5830 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_32_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_32_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5756 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_33_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_33_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5748 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_34_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_34_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5788 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_35_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_35_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5766 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_36_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_36_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5701 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_37_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_37_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5709 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_38_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_38_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5727 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_39_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_39_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5772 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_40_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_40_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5742 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_41_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_41_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5843 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_42_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_42_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5793 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_43_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_43_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5696 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_44_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_44_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5735 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_45_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_45_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5709 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_46_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_46_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5715 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_47_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_47_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5752 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_48_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_48_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5681 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_49_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_49_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5764 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_50_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_50_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5758 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_51_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_51_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5710 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_52_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_52_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5719 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_53_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_53_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5779 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_54_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_54_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5672 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_55_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_55_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5739 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_56_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_56_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5775 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_57_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_57_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5696 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_58_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_58_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5728 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_59_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_59_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5782 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_60_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_60_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5766 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_61_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_61_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5761 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_62_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_62_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5710 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_63_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_63_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5715 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_64_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_64_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5756 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_65_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_65_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5727 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_66_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_66_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5655 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_67_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_67_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5787 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_68_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_68_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5763 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_69_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_69_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5716 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_70_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_70_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5749 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_71_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_71_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5779 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_72_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_72_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5722 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_73_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_73_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5727 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_74_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_74_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5744 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_75_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_75_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5755 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_76_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_76_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5812 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_77_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_77_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5775 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_78_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_78_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5746 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_79_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_79_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5748 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_80_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_80_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5798 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_81_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_81_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5720 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_82_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_82_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5645 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_83_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_83_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5751 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_84_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_84_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5770 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_85_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_85_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5745 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_86_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_86_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5758 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_87_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_87_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5673 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_88_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_88_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5808 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_89_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_89_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5750 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_90_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_90_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5734 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_91_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_91_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5711 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_92_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_92_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5688 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/4/random_1000_4_1000_93_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/4/random_1000_4_1000_93_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5739 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# ...
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5767 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_69_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_69_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5759 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_70_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_70_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5813 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_71_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_71_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5773 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_72_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_72_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5743 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_73_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_73_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5780 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_74_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_74_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5798 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_75_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_75_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5770 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_76_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_76_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5696 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_77_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_77_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5709 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_78_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_78_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5714 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_79_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_79_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5760 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_80_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_80_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5795 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_81_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_81_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5752 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_82_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_82_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5669 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_83_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_83_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5737 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_84_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_84_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5778 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_85_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_85_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5774 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_86_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_86_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5778 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_87_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_87_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5716 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_88_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_88_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5796 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_89_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_89_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5745 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_90_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_90_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5686 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_91_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_91_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5803 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_92_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_92_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5740 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_93_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_93_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5732 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_94_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_94_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5812 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_95_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_95_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5729 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_96_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_96_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5755 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_97_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_97_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5716 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_98_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_98_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5679 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_edge_len/64/random_1000_4_1000_99_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_edge_len/64/random_1000_4_1000_99_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5825 byte
#   Writing dictionary
#   Writing finished
