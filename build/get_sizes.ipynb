# %%
##GET SIZES VAR EDGE LEN

# %%
from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "18_06_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4
min_version = 1
max_version = 10
#CHANGE
researched_path = "var_edge_len/"

#path_size = "/home/dtkhuat/results_version/size_"
#CHANGE
while str_len <= 64:

    #CHANGE
    researched = str(str_len)
    path_og = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    #path_size = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    path_incidence = "/home/dtkhuat/results_version/itr/random_graphs_compressed/"+researched_path +researched+"/"
    path_index = "/home/dtkhuat/results_version/version_itr/random_graphs_compressed/"+researched_path +researched+"/"

    for i in range(100):
        file_name = "random_"+str(num_node_labels)+"_4_"+str(num_edges)+"_"+ str(i)+ "_" +str(min_version) + "_" + str(max_version)
        compressed_name = file_name + "_c"
        
        with open(path_og+date+'.csv', 'a') as csv_file:
            fields = [file_name, os.stat(path_og + file_name).st_size, os.stat(path_incidence+compressed_name).st_size, os.stat(path_index+compressed_name).st_size]
            csv_writer = csv.writer(csv_file, delimiter=',')
            csv_writer.writerow(fields)

    #CHANGE
    str_len = str_len + 4

# %% [markdown]
# ##GET SIZES VAR NUM NODES

# %%
from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "18_06_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4
min_version = 1
max_version = 10
#CHANGE
researched_path = "var_num_nodes/"
increment = 1000
#path_size = "/home/dtkhuat/results_version/size_"
#CHANGE
while num_node_labels <= 10000:

    #CHANGE
    researched = str(num_node_labels)
    path_og = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    #path_size = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    path_incidence = "/home/dtkhuat/results_version/itr/random_graphs_compressed/"+researched_path +researched+"/"
    path_index = "/home/dtkhuat/results_version/version_itr/random_graphs_compressed/"+researched_path +researched+"/"

    for i in range(100):
        file_name = "random_"+str(num_node_labels)+"_4_"+str(num_edges)+"_"+ str(i)+ "_" +str(min_version) + "_" + str(max_version)
        compressed_name = file_name + "_c"
        
        with open(path_og+date+'.csv', 'a') as csv_file:
            fields = [file_name, os.stat(path_og + file_name).st_size, os.stat(path_incidence+compressed_name).st_size, os.stat(path_index+compressed_name).st_size]
            csv_writer = csv.writer(csv_file, delimiter=',')
            csv_writer.writerow(fields)

    #CHANGE
    num_node_labels = num_node_labels + increment

# %% [markdown]
# ##GET SIZES VAR NUM VERSIOn

# %%
from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "18_06_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4
min_version = 1
max_version = 10
#CHANGE
researched_path = "var_version/"
increment = 10
#path_size = "/home/dtkhuat/results_version/size_"
#CHANGE
while max_version <= 100:

    #CHANGE
    researched = str(max_version)
    path_og = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    #path_size = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    path_incidence = "/home/dtkhuat/results_version/itr/random_graphs_compressed/"+researched_path +researched+"/"
    path_index = "/home/dtkhuat/results_version/version_itr/random_graphs_compressed/"+researched_path +researched+"/"

    for i in range(100):
        file_name = "random_"+str(num_node_labels)+"_4_"+str(num_edges)+"_"+ str(i)+ "_" +str(min_version) + "_" + str(max_version)
        compressed_name = file_name + "_c"
        
        with open(path_og+date+'.csv', 'a') as csv_file:
            fields = [file_name, os.stat(path_og + file_name).st_size, os.stat(path_incidence+compressed_name).st_size, os.stat(path_index+compressed_name).st_size]
            csv_writer = csv.writer(csv_file, delimiter=',')
            csv_writer.writerow(fields)

    #CHANGE
    max_version = max_version + increment

# %% [markdown]
# GET SIZES VAR NUM EDGES

# %%
from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "18_06_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4
min_version = 1
max_version = 10
#CHANGE
researched_path = "var_num_edges/"
increment = 1000
#path_size = "/home/dtkhuat/results_version/size_"
#CHANGE
while num_edges <= 10000:

    #CHANGE
    researched = str(num_edges)
    path_og = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    #path_size = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    path_incidence = "/home/dtkhuat/results_version/itr/random_graphs_compressed/"+researched_path +researched+"/"
    path_index = "/home/dtkhuat/results_version/version_itr/random_graphs_compressed/"+researched_path +researched+"/"

    for i in range(100):
        file_name = "random_"+str(num_node_labels)+"_4_"+str(num_edges)+"_"+ str(i)+ "_" +str(min_version) + "_" + str(max_version)
        compressed_name = file_name + "_c"
        
        with open(path_og+date+'.csv', 'a') as csv_file:
            fields = [file_name, os.stat(path_og + file_name).st_size, os.stat(path_incidence+compressed_name).st_size, os.stat(path_index+compressed_name).st_size]
            csv_writer = csv.writer(csv_file, delimiter=',')
            csv_writer.writerow(fields)

    #CHANGE
    num_edges = num_edges + increment

# %% [markdown]
# GET SIZES REAL

# %%
from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "18_06_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4
min_version = 1
max_version = 10
#CHANGE
researched_path = "allData_p"
increment = 1000
#path_size = "/home/dtkhuat/results_version/size_"
#CHANGE
for file_num in range (1,11):

    #CHANGE
    researched = str(file_num)
    path_og = "/home/dtkhuat/preprocessed_files/final2/"+ researched_path + researched
    path_size = "/home/dtkhuat/results_version/size_real_"
    path_incidence = "/home/dtkhuat/results_version/itr/real_graphs_compressed/"+researched_path +researched + "_compressed2"
    path_index = "/home/dtkhuat/results_version/version_itr/real_graphs_compressed/"+researched_path +researched + "_compressed2"

    with open(path_size+date+'.csv', 'a') as csv_file:
        fields = ["allData_p"+researched, os.stat(path_og).st_size, os.stat(path_incidence).st_size, os.stat(path_index).st_size]
        csv_writer = csv.writer(csv_file, delimiter=',')
        csv_writer.writerow(fields)
