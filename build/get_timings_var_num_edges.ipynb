# %%
from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "18_06_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4
min_version = 1
max_version = 10

#CHANGE
increment = 1000
researched_path = "var_num_edges/"

while num_edges <= 10000:
    #CHANGE
    researched = str(num_edges)
    path_og = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    #path_incidence =  "/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_edge_len/"+researched+"/"
    path_index = "/home/dtkhuat/results_version/version_itr/random_graphs_compressed/"+researched_path +researched+"/"
    #call(["mkdir","/home/dtkhuat/results_version/random_graphs/"+researched_path+researched])
    #call(["mkdir",path_index])
    #call(["touch",path_og+date+".csv"])

    
    
    
    for i in range(0,100):
        file_name = "random_"+str(num_node_labels)+"_4_"+str(num_edges)+"_"
        compressed_name = file_name + str(i) +"_" +str(min_version)+"_" + str(max_version) +"_c"
        #call(["/home/dtkhuat/IncidenceTypeRePair/build/./cgraph-cli", "--overwrite", "--rrr", "--verbose", path_og + file_name + str(i)+".ttl",  path_incidence+compressed_name])
        call(["./cgraph-cli", "--overwrite", "--verbose","--format", "hyperedge", "--max-rank", "64" , path_og + file_name + str(i)+"_" +str(min_version)+"_" + str(max_version), path_index + compressed_name])

        '''
        with open(path_og+date+'.csv', 'a') as csv_file:
            fields = [file_name+ str(i)+".ttl", os.stat(path_og + file_name+ str(i)+".ttl").st_size, os.stat(path_incidence+compressed_name).st_size, os.stat(path_index+compressed_name).st_size]
            csv_writer = csv.writer(csv_file, delimiter=',')
            csv_writer.writerow(fields)
        '''
        if(i<99):
            with open('/home/dtkhuat/results_version/version_itr/times/'+ researched_path+ date+ '.csv', 'a') as csv_file:
               #csv_writer = csv.writer(csv_file, delimiter=',')
                csv_file.write(", ")
                csv_file.close()
            #with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+ researched_path+'/timings.csv', 'a') as csv_file:
                #csv_writer = csv.writer(csv_file, delimiter=',')
            #    csv_file.write(", ")
            #    csv_file.close()
        else:
            with open('/home/dtkhuat/results_version/version_itr/times/' + researched_path+ date+ '.csv', 'a') as csv_file:
                csv_file.write("\n")
                csv_file.close()
            #with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+ researched_path+'/timings.csv', 'a') as csv_file:
            #    csv_file.write("\n")
            #    csv_file.close()

    num_edges = num_edges + increment
# Out:
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_0_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_0_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5777 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_1_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_1_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5747 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_2_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_2_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5704 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_3_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_3_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5755 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_4_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_4_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5805 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_5_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_5_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5688 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_6_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_6_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5737 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_7_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_7_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5754 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_8_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_8_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5790 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_9_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_9_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5822 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_10_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_10_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5779 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_11_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_11_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5795 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_12_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_12_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5701 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_13_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_13_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5732 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_14_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_14_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5682 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_15_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_15_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5768 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_16_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_16_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5764 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_17_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_17_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5785 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_18_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_18_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5795 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_19_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_19_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5789 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_20_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_20_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5731 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_21_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_21_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5721 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_22_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_22_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5729 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_23_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_23_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5723 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_24_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_24_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5810 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_25_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_25_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5754 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_26_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_26_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5685 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_27_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_27_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5803 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_28_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_28_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5705 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_29_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_29_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5721 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_30_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_30_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5708 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_31_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_31_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5734 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_32_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_32_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5708 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_33_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_33_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5771 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_34_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_34_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5782 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_35_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_35_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5792 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_36_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_36_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5730 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_37_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_37_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5710 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_38_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_38_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5733 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_39_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_39_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5803 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_40_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_40_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5804 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_41_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_41_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5753 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_42_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_42_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5787 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_43_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_43_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5691 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_44_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_44_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5741 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_45_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_45_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5748 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_46_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_46_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5778 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_47_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_47_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5731 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_48_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_48_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5763 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_49_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_49_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5659 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_50_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_50_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5810 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_51_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_51_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5682 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_52_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_52_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5668 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_53_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_53_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5878 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_54_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_54_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5852 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_55_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_55_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5724 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_56_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_56_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5754 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_57_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_57_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5750 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_58_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_58_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5718 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_59_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_59_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5798 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_60_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_60_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5739 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_61_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_61_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5690 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_62_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_62_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5735 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_63_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_63_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5813 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_64_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_64_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5767 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_65_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_65_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5740 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_66_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_66_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5716 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_67_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_67_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5801 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_68_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_68_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5743 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_69_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_69_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5728 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_70_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_70_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5711 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_71_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_71_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5737 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_72_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_72_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5754 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_73_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_73_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5770 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_74_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_74_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5681 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_75_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_75_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5784 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_76_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_76_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5894 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_77_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_77_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5821 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_78_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_78_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5746 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_79_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_79_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5839 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_80_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_80_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5688 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_81_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_81_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5786 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_82_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_82_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5788 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_83_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_83_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5731 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_84_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_84_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5765 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_85_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_85_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5745 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_86_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_86_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5780 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_87_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_87_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5719 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_88_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_88_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5736 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_89_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_89_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5768 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_90_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_90_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5692 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_91_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_91_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5778 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/1000/random_1000_4_1000_92_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/1000/random_1000_4_1000_92_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
# ...
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_69_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 53014 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_70_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_70_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52227 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_71_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_71_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52547 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_72_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_72_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52752 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_73_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_73_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52621 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_74_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_74_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52461 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_75_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_75_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52793 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_76_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_76_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52729 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_77_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_77_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52858 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_78_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_78_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 53061 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_79_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_79_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52481 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_80_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_80_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52941 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_81_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_81_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52382 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_82_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_82_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52790 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_83_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_83_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52545 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_84_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_84_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 53132 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_85_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_85_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52423 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_86_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_86_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52842 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_87_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_87_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52922 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_88_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_88_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52806 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_89_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_89_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52683 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_90_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_90_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52705 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_91_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_91_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52127 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_92_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_92_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52546 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_93_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_93_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 53123 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_94_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_94_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52521 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_95_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_95_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52863 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_96_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_96_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 53028 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_97_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_97_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52856 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_98_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_98_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52694 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_num_edges/10000/random_1000_4_10000_99_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_num_edges/10000/random_1000_4_10000_99_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 52245 byte
#   Writing dictionary
#   Writing finished

# %%
from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "18_06_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4
min_version = 1
max_version = 10

#CHANGE
increment = 1000
researched_path = "var_num_edges/"

while num_edges <= 10000:
    #CHANGE
    researched = str(num_edges)
    path_og = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    path_incidence =  "/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_edge_len/"+researched+"/"
    #path_index = "/home/dtkhuat/results_version/version_itr/random_graphs_compressed/"+researched_path +researched+"/"
    #call(["mkdir","/home/dtkhuat/results_version/random_graphs/"+researched_path+researched])
    #call(["mkdir",path_index])
    #call(["touch",path_og+date+".csv"])

    
    
    
    for i in range(0,100):
        file_name = "random_"+str(num_node_labels)+"_4_"+str(num_edges)+"_"
        compressed_name = file_name + str(i) +"_" +str(min_version)+"_" + str(max_version) +"_c"
        call(["/home/dtkhuat/IncidenceTypeRePair/build/./cgraph-cli", "--overwrite", "--rrr", "--verbose","--max-rank", "64", path_og + file_name + str(i)+".ttl",  path_incidence+compressed_name])
        #call(["./cgraph-cli", "--overwrite", "--verbose","--format", "hyperedge", "--max-rank", "64" , path_og + file_name + str(i)+"_" +str(min_version)+"_" + str(max_version), path_index + compressed_name])

        '''
        with open(path_og+date+'.csv', 'a') as csv_file:
            fields = [file_name+ str(i)+".ttl", os.stat(path_og + file_name+ str(i)+".ttl").st_size, os.stat(path_incidence+compressed_name).st_size, os.stat(path_index+compressed_name).st_size]
            csv_writer = csv.writer(csv_file, delimiter=',')
            csv_writer.writerow(fields)
        '''
        if(i<99):
            #with open('/home/dtkhuat/results_version/version_itr/times/'+ researched_path+ date+ '.csv', 'a') as csv_file:
               #csv_writer = csv.writer(csv_file, delimiter=',')
            #    csv_file.write(", ")
            #    csv_file.close()
            with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+ researched_path+'/timings.csv', 'a') as csv_file:
                #csv_writer = csv.writer(csv_file, delimiter=',')
                csv_file.write(", ")
                csv_file.close()
        else:
            #with open('/home/dtkhuat/results_version/version_itr/times/' + researched_path+ date+ '.csv', 'a') as csv_file:
            #    csv_file.write("\n")
            #    csv_file.close()
            with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+ researched_path+'/timings.csv', 'a') as csv_file:
                csv_file.write("\n")
                csv_file.close()

    num_edges = num_edges + increment
