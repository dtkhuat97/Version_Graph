# %%
from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "17_07_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4
min_version = 1
max_version = 10

#CHANGE
increment = 10
researched_path = "var_version/"

while max_version <= 100:
    #CHANGE
    researched = str(max_version)
    path_og = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    #path_incidence =  "/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_edge_len/"+researched+"/"
    path_index = "/home/dtkhuat/results_version/version_itr/random_graphs_compressed/"+researched_path +researched+"/"
    #call(["mkdir","/home/dtkhuat/results_version/random_graphs/"+researched_path+researched])
    #call(["mkdir",path_index])
    #call(["touch",path_og+date+".csv"])

    
    
    
    for i in range(0,100):
        file_name = "random_"+str(num_node_labels)+"_4_"+str(num_edges)+"_"
        compressed_name = file_name + str(i) +"_" +str(min_version)+"_" + str(max_version) +"_c"
        #call(["/home/dtkhuat/IncidenceTypeRePair/build/./cgraph-cli", "--overwrite", "--rrr", "--verbose", path_og + file_name + str(i)+".ttl",  path_incidence+compressed_name])
        call(["./cgraph-cli", "--overwrite", "--verbose","--format", "hyperedge", "--max-rank", "64" , path_og + file_name + str(i)+"_" +str(min_version)+"_" + str(max_version), path_index + compressed_name])

        '''
        with open(path_og+date+'.csv', 'a') as csv_file:
            fields = [file_name+ str(i)+".ttl", os.stat(path_og + file_name+ str(i)+".ttl").st_size, os.stat(path_incidence+compressed_name).st_size, os.stat(path_index+compressed_name).st_size]
            csv_writer = csv.writer(csv_file, delimiter=',')
            csv_writer.writerow(fields)
        '''
        if(i<99):
            with open('/home/dtkhuat/results_version/version_itr/times/'+ researched_path+ date+ '.csv', 'a') as csv_file:
               #csv_writer = csv.writer(csv_file, delimiter=',')
                csv_file.write(", ")
                csv_file.close()
            #with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+ researched_path+'/timings.csv', 'a') as csv_file:
                #csv_writer = csv.writer(csv_file, delimiter=',')
            #    csv_file.write(", ")
            #    csv_file.close()
        else:
            with open('/home/dtkhuat/results_version/version_itr/times/' + researched_path+ date+ '.csv', 'a') as csv_file:
                csv_file.write("\n")
                csv_file.close()
            #with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+ researched_path+'/timings.csv', 'a') as csv_file:
            #    csv_file.write("\n")
            #    csv_file.close()

    max_version = max_version + increment
# Out:
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_version/10/random_1000_4_1000_0_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_version/10/random_1000_4_1000_0_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 5759 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# Parsing Hyperedge file /home/dtkhuat/results_version/random_graphs/var_version/10/random_1000_4_1000_1_1_10
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/version_itr/random_graphs_compressed/var_version/10/random_1000_4_1000_1_1_10_c
#   Writing magic
#   Writing meta
# ...

# %%
## NEW VAR NUM VERSION TIMING

# %%
from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "17_07_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4
min_version = 1
max_version = 10

#CHANGE
increment = 10
researched_path = "var_version/"

while max_version <= 100:
    #CHANGE
    researched = str(max_version)
    #path_og = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"

    path_og = "/home/dtkhuat/results/random_graphs/var_num_nodes/" + str(1000) + "/"
    path_incidence =  "/home/dtkhuat/results_version/itr2/random_graphs_compressed/"+researched_path +researched+"/"
    #path_index = "/home/dtkhuat/results_version/itr2/random_graphs_compressed/"+researched_path +researched+"/"
    #path_index = "/home/dtkhuat/results_version/version_itr/random_graphs_compressed/"+researched_path +researched+"/"
    #call(["mkdir","/home/dtkhuat/results_version/random_graphs/"+researched_path+researched])
    #call(["mkdir",path_index])
    #call(["touch",path_og+date+".csv"])

    
    
    
    for i in range(0,100):
        file_name = "random_"+str(num_node_labels)+"_4_"+str(num_edges)+"_" 
        compressed_name = file_name + str(i) +"_" +str(min_version)+"_" + str(max_version) +"_c"
        call(["/home/dtkhuat/IncidenceTypeRePair/build/./cgraph-cli", "--overwrite", "--rrr", "--verbose", "--max-rank", "64" , path_og + file_name + str(i)+ ".ttl",  path_incidence+compressed_name])
        #call(["./cgraph-cli", "--overwrite", "--verbose","--format", "hyperedge", "--max-rank", "64" , path_og + file_name + str(i)+"_" +str(min_version)+"_" + str(max_version), path_index + compressed_name])

        '''
        with open(path_og+date+'.csv', 'a') as csv_file:
            fields = [file_name+ str(i)+".ttl", os.stat(path_og + file_name+ str(i)+".ttl").st_size, os.stat(path_incidence+compressed_name).st_size, os.stat(path_index+compressed_name).st_size]
            csv_writer = csv.writer(csv_file, delimiter=',')
            csv_writer.writerow(fields)
        '''
        if(i<99):
            #with open('/home/dtkhuat/results_version/version_itr/times/'+ researched_path+ date+ '.csv', 'a') as csv_file:
               #csv_writer = csv.writer(csv_file, delimiter=',')
            #    csv_file.write(", ")
            #    csv_file.close()
            with open('/home/dtkhuat/results_version/itr2/times/var_version/'+ date +'.csv', 'a') as csv_file:
                #csv_writer = csv.writer(csv_file, delimiter=',')
                csv_file.write(", ")
                csv_file.close()
        else:
            #with open('/home/dtkhuat/results_version/version_itr/times/' + researched_path+ date+ '.csv', 'a') as csv_file:
            #    csv_file.write("\n")
            #    csv_file.close()
            with open('/home/dtkhuat/results_version/itr2/times/var_version/'+date+'.csv', 'a') as csv_file:
                csv_file.write("\n")
                csv_file.close()

    max_version = max_version + increment
# Out:
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_nodes/1000/random_1000_4_1000_0.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/itr2/random_graphs_compressed/var_version/10/random_1000_4_1000_0_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
#     Grammar Size is 3946 byte
#   Writing dictionary
#   Writing finished
# Compression parameters:
# - max-rank: 64
# - monograms: false
# - factor: 64
# - sampling: 0
# - rle: true
# - nt-table: true
# - rrr: true
# Parsing RDF file /home/dtkhuat/results/random_graphs/var_num_nodes/1000/random_1000_4_1000_1.ttl
# Applying repair compression
# Writing compressed graph to /home/dtkhuat/results_version/itr2/random_graphs_compressed/var_version/10/random_1000_4_1000_1_1_10_c
#   Writing magic
#   Writing meta
#   Writing grammar
# ...

# %%
from subprocess import call
import csv
import os

#compressed_name = "dnb_set=authorities_partition=werk_compressed"


date = "17_07_2024"
num_node_labels = 1000
num_edge_labels = 4
num_edges = 1000
str_len = 4
min_version = 1
max_version = 10

#CHANGE
increment = 10
researched_path = "var_version/"

while max_version <= 100:
    #CHANGE
    researched = str(max_version)
    path_og = "/home/dtkhuat/results_version/random_graphs/"+ researched_path + researched + "/"
    #path_incidence =  "/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/var_edge_len/"+researched+"/"
    path_index = "/home/dtkhuat/results_version/version_itr/random_graphs_compressed/"+researched_path +researched+"/"
    #call(["mkdir","/home/dtkhuat/results_version/random_graphs/"+researched_path+researched])
    #call(["mkdir",path_index])
    #call(["touch",path_og+date+".csv"])

    
    
    
    for i in range(0,100):
        file_name = "random_"+str(num_node_labels)+"_4_"+str(num_edges)+"_"
        compressed_name = file_name + str(i) +"_" +str(min_version)+"_" + str(max_version) +"_c"
        #call(["/home/dtkhuat/IncidenceTypeRePair/build/./cgraph-cli", "--overwrite", "--rrr", "--verbose", path_og + file_name + str(i)+".ttl",  path_incidence+compressed_name])
        call(["./cgraph-cli", "--overwrite", "--verbose","--format", "hyperedge", "--max-rank", "64" , path_og + file_name + str(i)+"_" +str(min_version)+"_" + str(max_version), path_index + compressed_name])

        '''
        with open(path_og+date+'.csv', 'a') as csv_file:
            fields = [file_name+ str(i)+".ttl", os.stat(path_og + file_name+ str(i)+".ttl").st_size, os.stat(path_incidence+compressed_name).st_size, os.stat(path_index+compressed_name).st_size]
            csv_writer = csv.writer(csv_file, delimiter=',')
            csv_writer.writerow(fields)
        '''
        if(i<99):
            with open('/home/dtkhuat/results_version/version_itr/times/'+ researched_path+ date+ '.csv', 'a') as csv_file:
               #csv_writer = csv.writer(csv_file, delimiter=',')
                csv_file.write(", ")
                csv_file.close()
            #with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+ researched_path+'/timings.csv', 'a') as csv_file:
                #csv_writer = csv.writer(csv_file, delimiter=',')
            #    csv_file.write(", ")
            #    csv_file.close()
        else:
            with open('/home/dtkhuat/results_version/version_itr/times/' + researched_path+ date+ '.csv', 'a') as csv_file:
                csv_file.write("\n")
                csv_file.close()
            #with open('/home/dtkhuat/results/random_graphs_compressed/IncidenceRePair_compressed/'+ researched_path+'/timings.csv', 'a') as csv_file:
            #    csv_file.write("\n")
            #    csv_file.close()

    max_version = max_version + increment
